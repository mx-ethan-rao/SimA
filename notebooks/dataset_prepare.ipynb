# %%
import numpy as np
from pathlib import Path

# -------- parameters --------
total_images = 60_000
train_size   = total_images // 2          # 30 000
outfile      = Path("celeba_mia_halves.npz")
rng_seed     = 42                         # change/omit for a new random split
# ----------------------------

# 1. shuffle all indices reproducibly
rng     = np.random.default_rng(rng_seed)
indices = np.arange(total_images)
rng.shuffle(indices)

# 2. split 50 / 50
mia_train_idxs = indices[:train_size]     # shape (30_000,)
mia_eval_idxs  = indices[train_size:]     # shape (30_000,)

# 3. save both arrays to one NPZ
np.savez(outfile,
         mia_train_idxs=mia_train_idxs,
         mia_eval_idxs=mia_eval_idxs)

print(f"Saved to {outfile.resolve()}")
# Out:
# Saved to /home/ethanrao/MIA_test/celeba_mia_halves.npz

# %%
#!/usr/bin/env python3
# split_pokemon_blip.py
from pathlib import Path
from datasets import load_dataset, DatasetDict, disable_caching

# ----------------------------------------------------------------------
# CONFIG – adjust these three lines if you need different paths / seed
# ----------------------------------------------------------------------
# CACHE_DIR      = "./hf_cache"          # where the raw download is cached
SAVE_DIR       = Path("/banana/ethan/MIA_data/POKEMON/pokemon_blip_splits")  # final dataset on disk
RANDOM_SEED    = 42                    # makes the 416/417 split reproducible
# ----------------------------------------------------------------------

def main() -> None:
    # 1. download the original (single-split) dataset
    full_ds = load_dataset(
        "reach-vb/pokemon-blip-captions",
        split="train",
        # cache_dir=CACHE_DIR,
    )                                    # → Dataset with 833 rows

    # 2. shuffle & split 416 / 417
    split_ds: DatasetDict = full_ds.train_test_split(
        test_size=417,                   # the remainder (416) becomes train
        shuffle=True,
        seed=RANDOM_SEED,
    )
    assert len(split_ds["train"]) == 416
    assert len(split_ds["test"])  == 417

    # 3. save to disk in Arrow format (incl. images)
    SAVE_DIR.mkdir(parents=True, exist_ok=True)
    split_ds.save_to_disk(str(SAVE_DIR))
    print(f"✅  Saved dataset with splits {list(split_ds.keys())} to {SAVE_DIR}")

if __name__ == "__main__":
    disable_caching()  # optional: avoids filling ~/.cache/huggingface/datasets
    main()
# Out:
# Generating train split:   0%|          | 0/833 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/416 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/417 [00:00<?, ? examples/s]
# ✅  Saved dataset with splits ['train', 'test'] to /banana/ethan/MIA_data/POKEMON/pokemon_blip_splits

# %%
from datasets import load_from_disk
dataset = load_from_disk("/banana/ethan/MIA_data/POKEMON/pokemon_blip_splits")                            # returns a DatasetDict with "train" & "test"

# %%
next(iter(dataset['train']))
# len(dataset['test'])
# Out:
# {'image': <PIL.Image.Image image mode=RGB size=1280x1280>,
#  'text': 'a cartoon animal with a pink ball on its head'}

# %%
#!/usr/bin/env python3
# build_coco2017_val_train_test.py
#
# Requires: pip install "datasets>=2.19.0" requests
# ---------------------------------------------------------------------
from pathlib import Path
import requests
from datasets import load_dataset, DatasetDict, Image, disable_caching

# ----------- configuration ---------------------------------------------------
# CACHE_DIR   = "./hf_cache"                    # raw HF cache
SAVE_DIR    = Path("/banana/ethan/MIA_data/MSCOCO/coco2017_val_splits")   # final dataset directory
IMG_DIR     = SAVE_DIR / "images"             # where JPEGs will live
RANDOM_SEED = 2025
NUM_PROC    = 8                              # parallel download workers
TIMEOUT_S   = 10
# -----------------------------------------------------------------------------

def download_to_local(example):
    """Download one COCO image and write its local path back into the row."""
    url = example["coco_url"]
    local_path = IMG_DIR / example["file_name"]       # e.g. images/val2017/000000397133.jpg
    local_path.parent.mkdir(parents=True, exist_ok=True)

    if not local_path.exists():                       # skip if already present
        resp = requests.get(url, timeout=TIMEOUT_S)
        resp.raise_for_status()
        local_path.write_bytes(resp.content)

    example["image"] = str(local_path)                # new column
    return example

def main() -> None:
    # 1. Load the 5 000-row validation split metadata
    ds = load_dataset(
        "phiyodr/coco2017",
        split="validation",
        # cache_dir=CACHE_DIR,
    )

    # 2. Download every JPEG locally & add an 'image' column with the file path
    ds = ds.map(download_to_local, num_proc=NUM_PROC)

    # 3. Keep only 'image' + 'captions', rename 'captions' -> 'text'
    ds = ds.remove_columns(
        [c for c in ds.column_names if c not in {"image", "captions"}]
    )

    # 4. Tell 🤗 Datasets that 'image' is an Image feature (decodes on access)
    ds = ds.cast_column("image", Image())

    # 5. Shuffle once, slice 2 500 / 2 500 into train / test
    ds = ds.shuffle(seed=RANDOM_SEED)
    split_ds = DatasetDict({
        "train": ds.select(range(2_500)),
        "test" : ds.select(range(2_500, 5_000)),
    })

    # 6. Persist to disk in Arrow format
    SAVE_DIR.mkdir(parents=True, exist_ok=True)
    split_ds.save_to_disk(str(SAVE_DIR))
    print(f"✅  Saved to {SAVE_DIR} (train {len(split_ds['train'])}, "
          f"test {len(split_ds['test'])})")

if __name__ == "__main__":
    disable_caching()     # optional – keeps ~/.cache/huggingface tidy
    main()
# Out:
# Generating train split:   0%|          | 0/118287 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5000 [00:00<?, ? examples/s]
# Map (num_proc=8):   0%|          | 0/5000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2500 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/2500 [00:00<?, ? examples/s]
# ✅  Saved to /banana/ethan/MIA_data/MSCOCO/coco2017_val_splits (train 2500, test 2500)

# %%
from datasets import load_from_disk
dataset = load_from_disk("/banana/ethan/MIA_data/MSCOCO/coco2017_val_splits")                            # returns a DatasetDict with "train" & "test"

# %%
# len(dataset['test'len])
len(dataset['train'])
# Out:
# 2500

# %%
#!/usr/bin/env python3
# build_flickr30k_20k_train_test.py
#
# pip install "datasets>=2.19.0"
# ----------------------------------------------------------------------
from pathlib import Path
from datasets import load_dataset, DatasetDict, Image, disable_caching

# -------------------- CONFIG (edit if you like) -----------------------
# CACHE_DIR   = "./hf_cache"
SAVE_DIR    = Path("/banana/ethan/MIA_data/FLICKR/flickr30k_splits")
RANDOM_SEED = 2025
SAMPLE_SIZE = 20_000                         # 20 k from the train split
# ----------------------------------------------------------------------

def main() -> None:
    # 1. Load the official Flickr-30k *train* split
    ds = load_dataset(
        "nlphuji/flickr30k",
        split="test",                       # 145 k rows
        # cache_dir=CACHE_DIR,
    )

    # 2. Shuffle and down-sample to 20 k
    ds = ds.shuffle(seed=RANDOM_SEED).select(range(SAMPLE_SIZE))

    # 3. Keep only 'image' and 'sentence', rename → 'text'
    ds = (
        ds.remove_columns([c for c in ds.column_names if c not in {"image", "caption"}]).cast_column("image", Image())     # ensures PIL decoding on access
    )

    # 4. Slice 10 k / 10 k into train / test
    split_ds = DatasetDict({
        "train": ds.select(range(10_000)),
        "test" : ds.select(range(10_000, SAMPLE_SIZE)),
    })

    # 5. Persist to disk (Arrow format)
    SAVE_DIR.mkdir(parents=True, exist_ok=True)
    split_ds.save_to_disk(str(SAVE_DIR))
    print(f"✅  Saved Flickr-30k sample to {SAVE_DIR}"
          f" (train={len(split_ds['train'])}, test={len(split_ds['test'])})")

if __name__ == "__main__":
    disable_caching()         # optional – keeps ~/.cache/huggingface tidy
    main()
# Out:
# Saving the dataset (0/3 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# Saving the dataset (0/3 shards):   0%|          | 0/10000 [00:00<?, ? examples/s]
# ✅  Saved Flickr-30k sample to /banana/ethan/MIA_data/FLICKR/flickr30k_splits (train=10000, test=10000)

# %%
from datasets import load_from_disk
dataset = load_from_disk("/banana/ethan/MIA_data/FLICKR/flickr30k_splits")

# %%
print(len(dataset['train']))
dataset.column_names
dataset['train'][0]
# Out:
# 10000
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x500>,
#  'caption': ['Male players wearing red and blue striped jerseys with yellow numbers hug each other.',
#   'Three soccer players in red and blue striped shirts hugging on a soccer field.',
#   'Two soccer players are embracing while 2 more approach to also hug them.',
#   'Members of a soccer team hugging on the field.',
#   'Three men celebrating a goal in the game.']}

# %%
#!/usr/bin/env python3
# build_laion_aesthetic_v2_5plus_5k.py
#
#   pip install "datasets>=2.19.0" requests tqdm
# ----------------------------------------------------------------------
from pathlib import Path
from typing import Dict
import hashlib, os, random, urllib.parse, requests, tqdm
from datasets import (
    load_dataset,
    Features,
    Image,
    Value,
    Dataset,
    disable_caching,
)

# ---------------- CONFIG -------------------------------------------------
SAVE_DIR    = Path("/banana/ethan/MIA_data/LAION5k/laion_aesthetic_v2_5plus_5k")
IMG_DIR     = SAVE_DIR / "images"
SAMPLE_SIZE = 2700                   # final rows you want
RANDOM_SEED = 2025
TIMEOUT_S   = 10
HEADERS     = {"User-Agent": "laion-5k-downloader"}
# ------------------------------------------------------------------------


def is_v2_5plus(row: Dict) -> bool:
    score = (
        row.get("AESTHETIC_SCORE")
        or row.get("aesthetic_score")
        or row.get("aesthetic")
    )
    p_wm = (
        row.get("p_watermark")
        or row.get("pwatermark")
        or row.get("P_WATERMARK")
    )
    return score is not None and p_wm is not None and score > 5.0 and p_wm < 0.5


def short_filename(row: Dict) -> str:
    """<hash>.ext   – keeps filenames < 40 chars."""
    base = row.get("hash") or hashlib.sha1(row["URL"].encode()).hexdigest()
    ext = os.path.splitext(urllib.parse.urlparse(row["URL"]).path)[1].lower()
    if ext not in {".jpg", ".jpeg", ".png", ".webp"}:
        ext = ".jpg"
    return f"{base}{ext}"


def download_image(url: str, local: Path) -> bool:
    try:
        r = requests.get(url, timeout=TIMEOUT_S, headers=HEADERS)
        r.raise_for_status()
        local.parent.mkdir(parents=True, exist_ok=True)
        local.write_bytes(r.content)
        return local.stat().st_size > 10_000
    except Exception:
        return False


def main() -> None:
    random.seed(RANDOM_SEED)
    disable_caching()
    SAVE_DIR.mkdir(parents=True, exist_ok=True)

    print("▶ Streaming LAION-2B-en-aesthetic, collecting v2 5+ rows…")
    stream = load_dataset(
        "laion/laion2B-en-aesthetic",
        split="train",
        streaming=True,
    ).shuffle(buffer_size=250_000, seed=RANDOM_SEED)

    good_rows = []
    for row in tqdm.tqdm(stream, desc="Sampling", unit="rows"):
        if not is_v2_5plus(row):
            continue

        fname = short_filename(row)
        local_path = IMG_DIR / fname[:2] / fname
        if local_path.exists() and local_path.stat().st_size > 10_000:
            ok = True
        else:
            ok = download_image(row["URL"], local_path)

        if ok:
            good_rows.append({"image": str(local_path), "text": row.get("TEXT", "")})
            print(len(good_rows))

        if len(good_rows) == SAMPLE_SIZE:
            break

    print(f"✔ Collected {len(good_rows)} images; building Dataset…")

    features = Features({"image": Image(), "text": Value("string")})
    ds = Dataset.from_list(good_rows, features=features)
    ds.save_to_disk(str(SAVE_DIR))
    print(f"✅  Saved train-only split to {SAVE_DIR}")


if __name__ == "__main__":
    main()

# %%
#!/usr/bin/env python3
# build_laion2B_multi_ascii_v25_2500.py
#
#   pip install "datasets>=2.19.0" requests tqdm
# ----------------------------------------------------------------------
import hashlib, os, random, re, urllib.parse, requests, tqdm
from pathlib import Path
from typing import Dict
from datasets import (
    load_dataset,
    disable_caching,
    Dataset,
    Features,
    Image,
    Value,
)

# ---------------- CONFIG ------------------------------------------------
SAVE_DIR    = Path("/banana/ethan/MIA_data/LAION5k/laion2B_multi_ascii_v25_2500")
IMG_DIR     = SAVE_DIR / "images"
TARGET_ROWS = 2_700
RNG_SEED    = 2025
TIMEOUT_S   = 10
HEADERS     = {"User-Agent": "laion-2500-downloader"}
ASCII_RE    = re.compile(r"^[\x00-\x7F]+$")      # only ASCII chars
# -----------------------------------------------------------------------


def ascii_only(text: str) -> bool:
    return bool(ASCII_RE.fullmatch(text))


def v25_pass(row: Dict) -> bool:
    score = row.get("AESTHETIC_SCORE") or row.get("aesthetic_score") or row.get("prediction")
    p_wm  = row.get("p_watermark") or row.get("pwatermark") or row.get("P_WATERMARK")
    sim  = row.get("similarity")
    try:
        return score is not None and p_wm is not None and sim is not None and score > 5.0 and p_wm < 0.5 and sim > 0.3
    except TypeError:
        return False


def short_name(row: Dict) -> str:
    base = row.get("hash") or hashlib.sha1(row["URL"].encode()).hexdigest()
    ext  = os.path.splitext(urllib.parse.urlparse(row["URL"]).path)[1].lower()
    if ext not in {".jpg", ".jpeg", ".png", ".webp"}:
        ext = ".jpg"
    return f"{base}{ext}"


def fetch(url: str, dest: Path) -> bool:
    try:
        r = requests.get(url, timeout=TIMEOUT_S, headers=HEADERS)
        r.raise_for_status()
        dest.parent.mkdir(parents=True, exist_ok=True)
        dest.write_bytes(r.content)
        return dest.stat().st_size > 10_000
    except Exception:
        return False


def main() -> None:
    random.seed(RNG_SEED)
    disable_caching()
    SAVE_DIR.mkdir(parents=True, exist_ok=True)

    print("▶ Streaming laion2B-multi-translated, applying ASCII + v2 5+ filters …")
    stream = load_dataset(
        "laion/laion2B-multi-joined-translated-to-en",
        split="train",
        streaming=True,
    ).shuffle(buffer_size=100_000, seed=RNG_SEED)

    rows = []
    for row in tqdm.tqdm(stream, desc="Sampling", unit="rows"):
        text = row.get("ENG TEXT", "") or row.get("eng_text", "")
        if not text or not ascii_only(text):
            continue
        if not v25_pass(row):
            continue

        fname = short_name(row)
        local = IMG_DIR / fname[:2] / fname
        ok = local.exists() and local.stat().st_size > 10_000
        if not ok:
            ok = fetch(row["URL"], local)
        if not ok:
            continue

        rows.append({"image": str(local), "text": text})
        print(len(rows))
        if len(rows) == TARGET_ROWS:
            break

    print(f"✔ Collected {len(rows)} images; saving dataset …")

    features = Features({"image": Image(), "text": Value("string")})
    ds = Dataset.from_list(rows, features=features)
    ds.save_to_disk(str(SAVE_DIR))
    print(f"✅  Saved train-only split to {SAVE_DIR} ({len(ds)} rows)")


if __name__ == "__main__":
    main()

# %%
from datasets import load_from_disk
from pathlib import Path
from datasets import load_from_disk, Image, disable_caching
from PIL import Image as PILImage, UnidentifiedImageError

ds = load_from_disk('/banana/ethan/MIA_data/LAION5k/laion2B_multi_ascii_v25_2500')
disable_caching()
# ds = ds.cast_column("image", Image(decode=True))

cnt = 0
idx = []
for i in range(2700):
    try:
        print(type(ds[i]))
        # ds[i]
        idx.append(i)
        cnt += 1
        if cnt == 2500:
            break
    except:
        print(f'xxxx{i}')
        # idx.append(i)
print(len(idx))
clean = ds.select(idx)
clean.save_to_disk('/banana/ethan/MIA_data/LAION5k/laion2B_multi_ascii_v25_2500_clean')
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x400 at 0x7F858613A2D0>, 'text': '200 Victorian Sunroom Design Ideas & Remodel Pictures | Houzz'}
# {'image': <PIL.Image.Image image mode=RGB size=590x393 at 0x7F8586174850>, 'text': 'Father Teaching Son How To Play Basketball On Driveway At Home - Stock Photo - Images'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F8586174FD0>, 'text': 'Melissa Sweet Wedding Gown'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=672x840 at 0x7F8586176890>, 'text': 'View of Montage Deer Valley with Deer Valley Resort in the background'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x667 at 0x7F8586175910>, 'text': 'Grilled fillet steak with charred tomato and feta salad'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x266 at 0x7F8586176D90>, 'text': 'Colourful Autumn Background by Autumn Backgrounds Wallpapers Wallpaper Cave'}
# {'image': <PIL.Image.Image image mode=RGB size=700x1050 at 0x7F8586139850>, 'text': "Baskets & Blooms from a Glam Boho Unicorn Birthday Party on Kara's Party Ideas | KarasPartyIdeas.com (11)"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F85861C9310>, 'text': 'Flight Suit with Embroidered Cap for 18 Months Costume'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x640 at 0x7F85861CA810>, 'text': 'Fly Fishing – Beginners'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=790x524 at 0x7F85861C9310>, 'text': '1964 Shelby Cobra Daytona'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x7F85861C9ED0>, 'text': 'garage man cave ideas to be your private spot home design 2018 picture gallery for garage man cave ideas to be your private spot'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=295x171 at 0x7F85861C9ED0>, 'text': 'ubisoft announces year 3 ubisoft delays far cry 5 the crew 2 and another unannounced title'}
# {'image': <PIL.Image.Image image mode=RGB size=980x373 at 0x7F858612FE90>, 'text': 'Christmas Discount - Plush Fabric Teddy Bear Angel Ornament'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x200 at 0x7F85861C8FD0>, 'text': 'Traditional Irish Cottage with a Red Door and Red Decorative Items; Currabinny County Cork Ireland by Design Pics Inc'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x938 at 0x7F85861C9550>, 'text': 'Sweet Love Chocolate Tin Can'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x294 at 0x7F85861CB950>, 'text': 'Real Steel: Robotsessuale'}
# {'image': <PIL.Image.Image image mode=RGB size=500x368 at 0x7F85861396D0>, 'text': '3 Way Maple Crib From Crib to Toddler Bed to Youth Bed'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x500 at 0x7F85861C9110>, 'text': "Have fun in the sun on this BVI's 80' motor yacht charter"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=680x1020 at 0x7F85861C9250>, 'text': 'Caramelized Onion and Garlic Dip - a new version of a classic favorite, with caramelized shallots and roasted garlic! Best served with crunchy potato chips! | Fork in the Kitchen'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=796x598 at 0x7F85861CAD50>, 'text': 'Bournemouth beach huts Summer vacation outfits'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=420x295 at 0x7F85861CAD50>, 'text': "Tony Justice has been trucking about seventeen years, but he's also the opening act for John Anderson at GATS this year. He's produced three country music CD's (tonyjusticemusic.com) and has a large, extremely dedicated fan base in the trucking industry. He's actually kind of a big deal when it comes to country music, he's working with some legends in the industry these days, but when you ask him what he identifies as, he still says he's a trucker."}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7F8586139850>, 'text': 'Hop On Hop Off New York Map by Hop On And Off Bus Nyc The Best Bus'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=375x397 at 0x7F85CC2E7D10>, 'text': 'willow armchair by gustav stickley'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275 at 0x7F85CC2E7050>, 'text': '25+ Cute Wedding Venues Ontario Ideas On Pinterest | Rustic ... The Barn At Gibbet Hill Vintage Oaks Banquet Grand Opening Styled Shoot Central 75 Piureperfect Ideas For A Rustic Wedding Huffpost Weddings Georgia Venue In Stylish Outdoor Venues Pa 30 Best Outdoors Eclectic Wolf Creek Estates Stables North Kathleen Dans Diy Noubacomau Galleano Winery Inspiration Wisconsin Unique Weddings Unique 136 Best Images On Pinterest Venues Wedding Indiana And Michigan Entertaing'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x266 at 0x7F85CC2E7D10>, 'text': 'mercedes tuning z performance showcases new mercedes amg tuning project'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x7F85CC2E5ED0>, 'text': 'Bearded grandpa knitting warm woolen sweater or other knitwear at lesiure'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=470x403 at 0x7F85CC2E5ED0>, 'text': 'R20180425_wild-animal-babies-fabric-tile_grey_final_shop_preview'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x267 at 0x7F85CC2E5ED0>, 'text': 'Downton Abbey S02E04 (2).jpg'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=208x240 at 0x7F85CC2E7D10>, 'text': 'Rosemary twigs in a glass bowl'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x450 at 0x7F85CC2E6910>, 'text': 'DIY Princess Crown'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x250 at 0x7F85CC2E5ED0>, 'text': 'BMW R80 | by ER Motorcycles'}
# {'image': <PIL.Image.Image image mode=RGB size=849x566 at 0x7F85871F0690>, 'text': 'gartenhaus flachdach lounge gr e 1 weka typ 172 mit einzelt r holz haus bausatz gartenhaus. Black Bedroom Furniture Sets. Home Design Ideas'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=328x300 at 0x7F85861CB4D0>, 'text': "1940's Sprinkled Pink Retro Candy Gift Box"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x432 at 0x7F85861C9250>, 'text': 'Paul Dano plays the young Brian Wilson during the recording of <i>Pet Sounds</i> in <em>Love and Mercy</em>.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=205x246 at 0x7F85CC2E6910>, 'text': 'themed christmas decorations 30 exquisitely stunning christmas decorating ideas'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=825x619 at 0x7F85CC2E7090>, 'text': 'Woman holding Zulu face mask at craft market at the top of the Blyde River Canyon, South Africa'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=350x230 at 0x7F85CC2E75D0>, 'text': 'Receive Healing and Deliverance through Our Lady of Fatima'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F85861CB4D0>, 'text': '724 - Display cabinet, inlaid hardwood, stained glass and mirror, mid-20th century 132x100x30 cm...'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x7F85CC2E4250>, 'text': 'Bride & Groom - Chocolate Strawberries'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x675 at 0x7F8586175990>, 'text': 'A mural in a music room in Greenhills, Ohio.'}
# {'image': <PIL.Image.Image image mode=RGB size=1200x857 at 0x7F8586136490>, 'text': 'Woman on Bay State Road, Pigeon Cove'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7F8586137450>, 'text': 'Review Zoo Tycoon Xbox One Video Xbox Games For Children'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x7F8586137B90>, 'text': 'World Beach Boxing Fighting 17 Icon'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=422x750 at 0x7F85861353D0>, 'text': 'Kids Food Cooking Games'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=571x428 at 0x7F85861353D0>, 'text': 'A carpenter demonstrates a few replicas of first-century woodworking tools, including a plane and a drill. The woman is showing how wool was spun into thread, to be woven on a loom.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1250 at 0x7F8586176390>, 'text': 'A Winter Guide to Banff National Park'}
# {'image': <PIL.Image.Image image mode=RGB size=444x296 at 0x7F8586177450>, 'text': 'New forest engagement'}
# {'image': <PIL.Image.Image image mode=RGB size=650x350 at 0x7F85CC2D7690>, 'text': "Actor Yinka Quadri's P.A, 2 others arrested, arraigned for impersonating King Sunny Ade"}
# {'image': <PIL.Image.Image image mode=RGB size=237x237 at 0x7F85CC2E6A50>, 'text': 'Fruit & Scroll with Apples'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=990x339 at 0x7F85CC2E6A50>, 'text': 'Image result for river rafting'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x361 at 0x7F85CC2E6A50>, 'text': 'Property with pool'}
# {'image': <PIL.Image.Image image mode=RGB size=250x375 at 0x7F8586174510>, 'text': 'Romantic Boho Elopement'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F85CC2E6A50>, 'text': 'Marco Polo Italian Leather'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x450 at 0x7F85CC2E6A50>, 'text': 'A Long Time Exposure Of White River Falls A Powerful Multi-Tiered Waterfall by Greg Winston'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x713 at 0x7F85861396D0>, 'text': 'Russian Fur 25 best ideas about fur hats on russian hat'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=170x113 at 0x7F85CC2E4250>, 'text': 'stock photo of forlorn  - Rusty old car wreck - JPG'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x7F85871F3910>, 'text': 'Autumn harvest red apples fruits and sea buckthorn berry on a light gray wooden table background.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x320 at 0x7F85CC2E7B90>, 'text': 'Raisin Chess Pie Recipes'}
# {'image': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=200x170 at 0x7F858611F2D0>, 'text': 'Wholesale baby girl shoes newborn baby shoes'}
# {'image': <PIL.Image.Image image mode=RGBA size=400x300 at 0x7F858613A010>, 'text': 'Sparkle Photoshop Action light bright birds animal facebook instagram \xa0sparkles \xa0shine \xa0shimmer \xa0photoshop \xa0photography \xa0photo effect \xa0glow \xa0glitter \xa0effects actions'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x967 at 0x7F85861C8B90>, 'text': 'Gold Vases For Centerpieces'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x317 at 0x7F8586177450>, 'text': 'million newly listed french mansion  beverly hills'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=410x308 at 0x7F8586177450>, 'text': 'Rocket Launch Dribbble Drawing Icon Rockets Space'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=445x696 at 0x7F858611F0D0>, 'text': 'shabby chic decorating on a budget shabby chic decorating ideas on a budget of me'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=525x350 at 0x7F8586176D90>, 'text': 'flowers placed in large blue jugs overlooking the bay'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=450x298 at 0x7F85CC2E7C50>, 'text': 'Photo for Colorful illegal houses of the poor inhabitants of Luanda, Angola. These ghettos resemble Brasilian favelas. In the background the high rise buildings of the rich build a stark contrast. - Royalty Free Image'}
# {'image': <PIL.Image.Image image mode=RGB size=498x498 at 0x7F85CC2E6E10>, 'text': 'Plywood Easter Chick 10 Pack'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1067x1600 at 0x7F8586177050>, 'text': 'Flower-Crown-Shoot1-5.jpg'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=590x569 at 0x7F8586177050>, 'text': 'New Craftsman Stacking Tool Chest Storage System'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x616 at 0x7F8586176490>, 'text': 'indian bridal lengha'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x367 at 0x7F8586176490>, 'text': "El Pulpo Mexican Restaurant & Grill's Seafood Soup, named Siete Mares, was so popular as a special that it became a permanent item on the menu."}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x500 at 0x7F85CC2E6E10>, 'text': 'Low section of woman serving slice of cake at park'}
# {'image': <PIL.Image.Image image mode=RGB size=1280x1006 at 0x7F858612DCD0>, 'text': '1280x1006 Hoontoidly Roses Tumblr Drawing Images'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=563x327 at 0x7F85861772D0>, 'text': 'Beach House Pretty House Tours-Palm Beach Estate Picked For Country Video 20.jpg'}
# {'image': <PIL.Image.Image image mode=RGB size=200x200 at 0x7F8586137910>, 'text': "Close-up of child's lunch tray containing a sandwich made from whole wheat bread and lots of veggies, plus an apple and a cup of milk"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x2500 at 0x7F858611F2D0>, 'text': 'Depression glass American Sweetheart cup and saucer'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=189x300 at 0x7F85861CB4D0>, 'text': 'Greeting - Christmas. Santa Claus in brown robe  (Winsch)'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x266 at 0x7F85861CB950>, 'text': 'film jailangkung 2017 review eiff 2017 sweet virginia movie review world'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x355 at 0x7F85861CB950>, 'text': 'tiny home luxury tiny house town luxury tiny house in bend 280 sq ft'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x312 at 0x7F85CC2E7550>, 'text': "Cinderella Girls' Luxury Formal Ball Gown Dress Cosplay Costumes Princess Fairytale Blue Dress Halloween Christmas Carnival  Children's Day"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x315 at 0x7F8586176C10>, 'text': 'new cabin listing on the south lake tahoe mls'}
# {'image': <PIL.Image.Image image mode=RGB size=633x475 at 0x7F8586176C10>, 'text': "Marilyn Barner Anselmi's You Wouldn't Expect. August Wilson Theater, 2016. Photo Credit: Martha Rial"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=271x186 at 0x7F85CC2E72D0>, 'text': 'Image of: Front Pictures of Craftsman Style Houses'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=740x740 at 0x7F8586139310>, 'text': 'Snowshoer in Montana near Lolo. Snowshoeing is one of the top things to do in Montana in the winter.'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=539x310 at 0x7F85861CA110>, 'text': 'Downhill Champion- screenshot thumbnail'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x355 at 0x7F85861C88D0>, 'text': 'holden muscle car 100 holden muscle car aussie pride 13th new zealand'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=425x320 at 0x7F85CC2E72D0>, 'text': 'pizza sandwich'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x377 at 0x7F8586122290>, 'text': 'background with cup of coffee and Eiffel tower in Paris Fototapete'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x7F85861C8210>, 'text': 'Caravan trailer parked in a green summer garden near the country houses on a sunny day. Yellow wildflowers close-up. Idyllic rural landscape. Finland'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=870x1300 at 0x7F85CC2E6350>, 'text': 'How To Make French Crepes | #french #crepes #breakfast #dessert #dinner'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x7F85CC2E6A50>, 'text': '2009 Black Mustang Gt 2009 Ford Mustang Gt Foose Enforcer F154 Wheels Gloss Black W'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F8586139850>, 'text': 'Watercolor painting seamless pattern with llamas and cacti - 159149103'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=920x529 at 0x7F8586139310>, 'text': 'Runners make their way down Noe Street during the annual Santa Skivvies Run Sunday, Dec. 16, 2012. Four hundred volunteers and joggers took part, raising $43,000 for the AIDS Foundation. Runners started at the Lookout Bar on Market Street then ran through the Castro District taking a spontaneous route, much to the delight of onlookers. Photo: Lance Iversen, The Chronicle'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x367 at 0x7F85861CB4D0>, 'text': 'Maca Maple Chia Granola by The Kitchen Table by Nutiva'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x999 at 0x7F85861CB950>, 'text': 'Wyomissing Park Berks County Child Photographer'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x389 at 0x7F85861CB950>, 'text': 'Bone China LONDON COLLECTION schotel'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=568x568 at 0x7F85861CB950>, 'text': 'House under the moon'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1862x2834 at 0x7F85861CB950>, 'text': 'A tree house with a tire swing.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x500 at 0x7F85861CB950>, 'text': 'Abandoned rusty pressed piece of car No People Abandoned Garbage Metal Environmental Issues Steel Frame Rusty Pressed  Junkyard Broken Trash Pollution Motor Vehicle Waste Management Environment Obsolete Discarded Wreck Outdoors Day'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=276x183 at 0x7F858613B4D0>, 'text': 'fall table arrangements fall shower flowers on table where do we find the time'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x240 at 0x7F85CC2E6A50>, 'text': 'Simple Fall Table Decoration Ideas 11'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x7F858613A010>, 'text': 'outdoor office shed. Garden Shed Hut Wendy House Room Office Outdoor T'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x313 at 0x7F8586174FD0>, 'text': 'This Sept. 28, 2010, file photo shows Boston Celtics fan Justin Taylor Jr., 5, of Fall River, Mass., holds up a basketball to be autographed as Celtics forward Paul Pierce is greeted by students after their practice at NBA basketball training camp (AP).'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x7F85861C8B90>, 'text': "'Christmas Decorating Workshop - TUESDAY, DECEMBER 8th at 6:30 p.m. (THE COOKIE DECORATING STUDIO)"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360 at 0x7F85861C8B90>, 'text': "New Gardener's Guide to Shopping at a Garden Center"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=678x381 at 0x7F85861C8B90>, 'text': 'IN FOCUS// The Stranglers at Ulster Hall, Belfast, Northern Ireland 1'}
# {'image': <PIL.Image.Image image mode=RGB size=400x500 at 0x7F8586177250>, 'text': 'This is an image of Photograph & Poster of Audrey Hepburn 298126'}
# {'image': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=750x800 at 0x7F8586139950>, 'text': 'Lovely High Low Tulle   Flower     Girl     Dresses   With Shawl 2019 Crystal Appliqued   Dresses   For   Girls   Kids Prom   Dresses   vestido daminha'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x460 at 0x7F8586174890>, 'text': '5 ways data analytics can improve your communications strategy'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1300x975 at 0x7F858613A010>, 'text': 'Animals One Animal Animal Photography Animal Portrait No People Zoophotography Zoo Animals  Looking At Camera Snow Bamboo Bamboo Leaves Panda Red Panda'}
# {'image': <PIL.Image.Image image mode=RGB size=250x200 at 0x7F8586119550>, 'text': 'Asian Engagement Cookies'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x841 at 0x7F8586176D90>, 'text': 'Molang Mobile Wallpapers   Cute Kawaii Resources'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=650x504 at 0x7F8586176D90>, 'text': "Tips for Staging Your Home's Exterior This Summer"}
# {'image': <PIL.Image.Image image mode=RGB size=367x551 at 0x7F8586176D90>, 'text': 'River Grudie overshadowed by the mighty Slioch'}
# {'image': <PIL.Image.Image image mode=RGB size=1000x1493 at 0x7F8586135AD0>, 'text': 'Red Oak Weddings | Wedding + Lifestyle Blog for the Modern Couple in NY, NJ + PA | Engagements | Whimsical Imagery'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x7F8586176290>, 'text': 'Doctor holding bowl with products for heart-healthy diet, closeup'}
# {'image': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1024x1024 at 0x7F8586175990>, 'text': 'New Children Luminous Shoes Boys Girls Stripe Sport Running Shoes Baby Lights Fashion Sneakers Toddler Kids LED Sneakers'}
# {'image': <PIL.Image.Image image mode=RGB size=498x332 at 0x7F85861CA010>, 'text': 'Cereal or Chili Serving Bowl - Polish Pottery'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427 at 0x7F85861CA110>, 'text': 'three prunes in front of a plum'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x258 at 0x7F8586174DD0>, 'text': 'Bugatti Supercar Concept By Adrian Biggins Motivezine'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=683x1024 at 0x7F858611F0D0>, 'text': 'La Feria de Abril, Sevilla, Spain'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=604x402 at 0x7F85861CBDD0>, 'text': 'Musical Mini Cupcake Toppers'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x7F8586176290>, 'text': 'Hatch Chile Croque Monsieur'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=542x360 at 0x7F8586176B50>, 'text': 'Group of happy multiracial friends talking and laughing having a conversation at lunch'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x7F8586176490>, 'text': '"""Bridge to Nowhere"" in Whanganui National Park, New Zealand"'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x199 at 0x7F8586177190>, 'text': 'sackets-harbor-ny-wedding'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2500x1875 at 0x7F8586176550>, 'text': '1970 Ford Mustang Mach 1'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=350x350 at 0x7F8586176550>, 'text': 'Pocket Full of Love: A Valentine Craft to Promote Kindness In the Classroom'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=180x240 at 0x7F85861CA110>, 'text': 'A contestant in the 15th annual Howl-O-Ween dog costume'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=P size=647x680 at 0x7F85861C96D0>, 'text': 'Flowers and Leaves in Napkin for Thanksgiving'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=684x1023 at 0x7F8586176290>, 'text': 'united kingdom amazing selection official images Tuukka13 - Greetings from Berlin - WDYWT - Kris Van Assche ...'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F8586176290>, 'text': 'Picture of Classic 1957 Bel Air 2-Door Hardtop located in Texas Offered by a Private Seller - NMSZ'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1024 at 0x7F8586176C10>, 'text': 'Hell Bunny Hell Bunny Helen 50s Dress Red'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x7F858614BE50>, 'text': 'Fresh dairy products, milk, cottage cheese, eggs, yogurt, sour cream and butter on wooden table - fototapety na wymiar'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=850x640 at 0x7F858613B750>, 'text': "Cornbread and collard greens at Allie B's Cozy Kitchen on Clinton Ave. on Wednesday, Nov. 13, 2019 in Albany, N.Y. (Lori Van Buren/Times Union)"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x739 at 0x7F858613B750>, 'text': 'Milo Chocolate Cake With Chocolate Fudge Frosting Not'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x649 at 0x7F85861C96D0>, 'text': 'Clearing Storm, Downtown Truckee'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F85CC2D7690>, 'text': '2020 Chevrolet Corvette costs $59,995 to start, including fees'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x355 at 0x7F85CC2E6350>, 'text': '2004 acura nsx information and photos momentcar'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x481 at 0x7F85CC2E6290>, 'text': 'Dreams Punta Cana Resorts & Spa Image 14'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1250 at 0x7F8586175990>, 'text': 'Top tips for making Christmas healthier - Have a protein-rich breakfast!Stay hydratedEat mindfully (and slower than everyone else)Put healthy nibbles out along with the naughtier onesPause and breathe - do you really need another chocolate?'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360 at 0x7F8586175990>, 'text': 'Best of christmas decorating youtube for 2014 christmas tree decoration'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x355 at 0x7F8586137250>, 'text': 'garage sales dallas calling all car collector s luxury garages sotheby s'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x798 at 0x7F85CC2E72D0>, 'text': 'Rhossili Beach Gower Peninsula'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x664 at 0x7F8586135A90>, 'text': "Ray's Candy Store | Photo Credit: Find. Eat. Drink."}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=470x313 at 0x7F85CF3C4890>, 'text': 'The east front of Kensington Palace and gardens with the statue of Queen Victoria in the foreground, under a blue sky.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x355 at 0x7F8586139310>, 'text': 'cuisine and cook expert advice preparing cooking and freezing baby food'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x312 at 0x7F8586176C10>, 'text': 'Example of a transitional carpeted walk-in closet design in Los Angeles with white cabinets'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=530x405 at 0x7F8586176490>, 'text': 'Holy Hill In The Snow by Randy Scherkenbach'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x316 at 0x7F8586177190>, 'text': 'wedding ambiance cool lighting inspiration that will'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x284 at 0x7F85CC2E6290>, 'text': 'ford capri classic cars 1984 ford capri classic cars 1 flickr 1984 ford capri 1 6ls 5 speed sold car and classic'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F8586177610>, 'text': 'Florida beach and palm tree at sunrise original oil painting by PJ Cook.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x240 at 0x7F85861C88D0>, 'text': 'Hot House Tigers, Pair, Pink Green by Fab Funky'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=240x240 at 0x7F85861CBDD0>, 'text': 'Card for the holiday  with flowers on the abstract background'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x7F8586176850>, 'text': 'scary halloween wallpaper scary halloween decorating ideas 596 best diy halloween'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=324x235 at 0x7F85861C88D0>, 'text': "Evan's Orchard employee Leigh Ayres demonstrates the apple sorter for students from Anne Mason Elementary School (Scott County) Sept. 22, 2010. Photo by Amy Wallot"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x330 at 0x7F85861396D0>, 'text': "Kai Barber rushes for St. John's during the game Saturday, Oct. 19, 2019, against St. Thomas at Allianz Field in St. Paul."}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x334 at 0x7F8586137690>, 'text': 'group therapy - intensive outpatient program - aviary recovery center - st. louis intensive outpatient treatment - missiouri iop - drug and alcohol rehab'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x360 at 0x7F8586134410>, 'text': 'Man standing in an open field at sunset with open arms - embracing nature'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1040 at 0x7F8586137910>, 'text': 'Autumn | Frits Thaulow | Oil Painting'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=356x233 at 0x7F85CC2E6290>, 'text': 'TORRES DEL PAINE, CHILE - APRIL 4, 2015: Hotel Salto Chico Explora Patagonia at turquoise Lake Pehoe in Torres del Paine National Park, Patagonia, Chile'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=334x500 at 0x7F8586137690>, 'text': 'Dress With Cascading Draping   #longdress #elegantdress'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x267 at 0x7F8586139310>, 'text': 'Ron DeChant, bass, Starset'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x840 at 0x7F8586124450>, 'text': 'Guitar Decor For Bedroom Nice And Simple Clean Guitar Room Home Theater'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=460x230 at 0x7F85CC2E5AD0>, 'text': 'First Friday Pub Run : Red, White and Blue! AMERICA! tickets'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x1920 at 0x7F8586119550>, 'text': "Close-up Day Decoration Focus On Foreground Handmade Hanging Heart Shape No People Outdoors Valentine's Day"}
# {'image': <PIL.Image.Image image mode=RGB size=413x330 at 0x7F858614B090>, 'text': "LaMar's Small Off Grid Solar Cabin"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x314 at 0x7F8586175990>, 'text': 'corned beef and cabbage'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F8586175ED0>, 'text': 'Old Smokey Cabin - Rhododendron, OR Vacation Rental'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1061 at 0x7F858611AC90>, 'text': 'Mermaid Party Photo Booth Props'}
# {'image': <PIL.Image.Image image mode=RGB size=1000x750 at 0x7F85861C5A90>, 'text': "Lot 1 - LOT - CONTENTS OF LUNCHROOM TO INCLUDE: (9) 3' X 3' TABLES, (28) CHAIRS, GE CAROUSEL MICROWAVE, LG"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375 at 0x7F85861374D0>, 'text': '"""WW2 M1 possible candidate for """"restoration"""""""'}
# {'image': <PIL.Image.Image image mode=RGB size=600x600 at 0x7F85861CB4D0>, 'text': 'must try carnival food park in marikina booky'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=574x380 at 0x7F8586148C50>, 'text': 'Banana Chocolate-Chip Protein Souffle Muffins'}
# {'image': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=900x1287 at 0x7F85CC2E72D0>, 'text': 'Princess Portrait Neckline Illusion Beaded Lace And Tulle Off The Shoulder Wedding Dress A-Line Button Back Bridal Gowns'}
# {'image': <PIL.Image.Image image mode=RGB size=530x352 at 0x7F85CC2E72D0>, 'text': "Julianne's Sweet Sixteen at Whitby Castle, NY"}
# {'image': <PIL.Image.Image image mode=RGB size=700x467 at 0x7F8586134C50>, 'text': "Drink Bottles from a Shabby Chic Alice In Wonderland Birthday Party via Kara's Party Ideas KarasPartyIdeas.com (31)"}
# {'image': <PIL.Image.Image image mode=RGB size=468x312 at 0x7F858613A010>, 'text': 'For-Such-A-Time-Events-Sun-Valley-Event-'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960 at 0x7F858613A010>, 'text': "Large Picture of Classic '64 Ford Galaxie 500 XL located in Georgia Offered by Streetside Classics - Atlanta - GMV3"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=492x328 at 0x7F8586174FD0>, 'text': 'Happy grandfather sitting with his grandson on boardwalk looking at each other - JRFF03186'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=560x316 at 0x7F8586174FD0>, 'text': 'Blendtec peppermint hot cocoa'}
# {'image': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1000x1100 at 0x7F85861C8B90>, 'text': 'Stain Wedding Gowns Simple Bridal Dresses Ball Gowns Wedding Dresses 2019 White Africa Bridal Gowns Cheap Wedding Dresses L39353'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F85CC2E6E10>, 'text': "Photo taken at Cruisin' Grand by Tighe J. on 4/6/2013"}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x163 at 0x7F8586174210>, 'text': 'Ugly Christmas Sweater Vector Art'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x7F85861C8B90>, 'text': 'Lemon bars 2'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360 at 0x7F8586174210>, 'text': 'DanDee Easter Musical Bunnies singing'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x300 at 0x7F85CC2E7C50>, 'text': 'Super Sidecars Seen On www.coolpicturegallery.us'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x563 at 0x7F85861C96D0>, 'text': 'Florentine Ham and Egg Breakfast Biscuits'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x960 at 0x7F8586139690>, 'text': 'Large Picture of 1974 TR6 located in Bedford Virginia - $11,795.00 Offered by East Coast Auto Source - PVWC'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x315 at 0x7F8586136850>, 'text': 'New Construction Homes Nj by New Homes In Hillsborough Nj New Construction Homes'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=520x342 at 0x7F8586137690>, 'text': 'Vegetable Soup'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x320 at 0x7F85CC2E5990>, 'text': 'Shrimp Salad'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x346 at 0x7F85CC2E4DD0>, 'text': 'The narrow trail of the Chief Mountain trail running between a forest of pine trees.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1200 at 0x7F85CC2E7550>, 'text': 'peterburg_bridge'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x200 at 0x7F8586136350>, 'text': 'Magnetawan River - Image: Magnetawan ON 2'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x515 at 0x7F8586177610>, 'text': 'A Wooden Cabin Shed which has been Pressure Treated. The wood is slightly faded in colour because of the pressure treatment. There are three windows on the side of the shed and the door is on a different side to these windows.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1536 at 0x7F85CC2D6C10>, 'text': 'Holiday Mixed Grain Pilaf with Red Chard'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=338x450 at 0x7F85CC2E6290>, 'text': 'Scarlet Tanager by Found Image Press'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=268x268 at 0x7F85CC2E4DD0>, 'text': 'Saint Jerome in Penitence'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=350x234 at 0x7F85CC2E4DD0>, 'text': 'Enter your dates to get the Positano hotel deal'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x7F8586136850>, 'text': 'Cleaning supplies'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x213 at 0x7F8586136690>, 'text': 'Pumpkin pie isn'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2033x2779 at 0x7F85CC2E72D0>, 'text': '"2 sizes of Drawstring bags made with ""Dogs at the Farmers Market"" fabrics"'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x321 at 0x7F85CC2E72D0>, 'text': 'garfield park conservatory enjoy illinois'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=660x495 at 0x7F8586175ED0>, 'text': 'CoolSprings Galleria has been set up for visits with Santa Claus since Nov. 9.'}
# {'image': <PIL.Image.Image image mode=RGB size=1000x750 at 0x7F8586137910>, 'text': "Sweet Potato Soup with Yellow Split Peas — Rhyann's (Rad)ventures"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F85CC2E6290>, 'text': 'cake-pops-de-nutella, nutella-cake-pops'}
# {'image': <PIL.Image.Image image mode=RGB size=600x721 at 0x7F85861C5B10>, 'text': 'Jacquard Stars Cardigan 2-8 Years'}
# {'image': <PIL.Image.Image image mode=RGB size=250x250 at 0x7F858613BE50>, 'text': 'Roller Cabinet Tool Chest Tool Trolley'}
# {'image': <PIL.Image.Image image mode=RGB size=500x423 at 0x7F858611F2D0>, 'text': 'Art Prints of Portraits in the Countryside by Gustave Caillebotte'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=284x202 at 0x7F8586177710>, 'text': 'Data (13-07-2019)- Muse, San Siro-18'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=595x793 at 0x7F8586177710>, 'text': 'Healthy Vegan Cinnamon Rolls'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=620x930 at 0x7F8586177710>, 'text': 'watercolor wedding cake'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x240 at 0x7F8586136350>, 'text': 'Printed roller blinds Chocolate Cup of hot chocolate and pieces of chocolat on dark concrete background'}
# {'image': <PIL.Image.Image image mode=RGB size=454x341 at 0x7F85861C88D0>, 'text': 'Important updates for AP Physics 1 Exam in 2021!'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x534 at 0x7F8586137910>, 'text': 'Downtown Minneapolis Skyline, Minneapolis at sunset'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x7F8586176490>, 'text': 'Spring/Autumn Children Boots Girls Boys Leather Zip Rubber Ankle Martin Boots Fashion Baby Boy Girl shoes For Kids Boots 21-30'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=980x509 at 0x7F85CC2E5AD0>, 'text': 'See the exact moment a photographer told these women they were beautiful.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2656x2656 at 0x7F8586136350>, 'text': 'Swiss Five Minute Repeater Pocket Watch With Partial Exhibition Front'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=460x345 at 0x7F858614BDD0>, 'text': 'Anchorage trolley takes your safety serious'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667 at 0x7F858612DCD0>, 'text': 'Lifestyle image of child sitting with a toy in front of a bouncy castle outside in her garden'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x168 at 0x7F8586174890>, 'text': 'Treehouse masters treehouse point Issaquah Wa Pete Nelson Master Treehouse Builder And Star Of The Tv Show Treehouse Masters Has Created Special Spots For People Among The Trees At Treehouse Point Curbed Seattle Pete Nelson Local Tree Whisperer And Pete Nelson Local Tree'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=610x167 at 0x7F8586177C50>, 'text': 'bigstock-Red-Apple-With-Engraved-Heart-49835729 MEDIUM'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F8586175990>, 'text': 'a patchwork quilt - with North Dakota icon'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x7F8586123950>, 'text': 'Couple with coffee cups in winter'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x357 at 0x7F8586137250>, 'text': 'Craft Paper Crafts - paper folding crafts for ye craft ideas'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=930x550 at 0x7F858613BE50>, 'text': "The exclusive private members club One°15 Marina Club is located at Sentosa Cove, Singapore's prime leisure district"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=316x421 at 0x7F85CC2E7B90>, 'text': 'persimmons-galore'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x210 at 0x7F8586175B10>, 'text': 'Cute Giraffe, Zebra, Lion Cub, Pelican, Under A Palm Tree. Cute Tropical Animals In Cartoon Style. Watercolor Concept, On An Isolated Background.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x405 at 0x7F858611F0D0>, 'text': 'Former Tennessee Titan Jevon Kearse greets fans before the Titans uniform reveal event held at Broadway and 1st Avenue in Nashville, Tenn., Wednesday, April 4, 2018.'}
# {'image': <PIL.Image.Image image mode=RGB size=329x400 at 0x7F8586134250>, 'text': '18th Century-Style Diamond-Point Armoire,  France Circa 1900'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=884x540 at 0x7F8586175ED0>, 'text': '2015 Scion xB - Slide 1'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=223x226 at 0x7F85CC2D6AD0>, 'text': 'detail of a cosmological diagram from a 15th century illuminated'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=230x306 at 0x7F8586134210>, 'text': 'Slouse Of Cake Clipart free cake clip pictures clipartix'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=965x1600 at 0x7F85CF3AF550>, 'text': 'Queen of Collars, from The Cloisters Playing Cards'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x563 at 0x7F85861CA810>, 'text': 'Italian Sausage and Pepper Stew'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=446x640 at 0x7F85CC2E6E10>, 'text': 'Flannel Carolyn PJs - front'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=270x270 at 0x7F8586134210>, 'text': 'beach babe by Beth Ann - Babies & Children Child Portraits ( ocean, beach, sunset, baby, girl,  )'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=499x472 at 0x7F85872E2F10>, 'text': 'Head Table Centerpiece'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=312x312 at 0x7F858613B750>, 'text': '75 most popular luxury home gym design ideas for 2019'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=P size=551x310 at 0x7F8586136A50>, 'text': 'Скачать Grand Theft Auto San Andreas (GTA SA) для Microsoft Lumia 435'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x400 at 0x7F8586136A50>, 'text': 'LION OF JUDAH SWEAT SUITS (Red)'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x640 at 0x7F85861CB4D0>, 'text': 'Empty phone box'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x632 at 0x7F85CC2E4DD0>, 'text': 'Creepy Handmade Dolls - 17 best images about voodoo dolls on'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=584x582 at 0x7F8586134210>, 'text': "Fresco, Catacomb of Sts. Marcellinus and Peter, Rome, early 4th Century showing the haemorrhissa being healed by touching Christ's garment (Mk 5:25–34)"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1199x800 at 0x7F8586134250>, 'text': 'Photograph from Peter Pan - lighting design by Johnathan Rainsforth'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x538 at 0x7F858611A150>, 'text': 'Arkansas Scout overcomes cancer to earn Eagle Scout Award'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x271 at 0x7F8586137910>, 'text': 'Mercedes Sls Amg by Mercedes Sls Amg Black Series 22 April 2017'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=298x470 at 0x7F85CC2E7B90>, 'text': 'Stained Glass - Jesus Holding The Holy Bible And Saints'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x7F85CC2E7B90>, 'text': 'National Taco Day'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x300 at 0x7F85CC2E7B90>, 'text': '34 Gorgeous Christmas Tablescapes And Centerpiece Ideas'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x266 at 0x7F858614BC90>, 'text': 'How To Make A Paper Box With A Lid - how to make a paper box easy paper box hd tutorial'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x550 at 0x7F858612DCD0>, 'text': '2010 Land Rover Range Rover Sport HSE / Range Rover Sport Supercharged'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x7F85871F3750>, 'text': 'Vegan Sloppy Joes for Memorial Day'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x188 at 0x7F85CC2E5ED0>, 'text': 'Utility Shed'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=170x296 at 0x7F85CC2E5ED0>, 'text': 'Christmas Tree Shops Salem Nh - 15 red nutcracker with picture frame christmas tree shops andthat'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x7F8586136A50>, 'text': 'indian classic and vintage motorcycles for sale'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x147 at 0x7F8586136A50>, 'text': 'Million Dollar Highway'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600 at 0x7F85CC2E5ED0>, 'text': "This year our boys celebrated their birthdays with a winter lumberjack birthday party ... complete with edible 'logs'! See how we made a lumberjack wonderland with these fun and whimsical ideas!"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x770 at 0x7F8586176290>, 'text': 'Beautiful 1970 Vintage dresses love stick'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F858728A890>, 'text': 'Nāpali Coast State Wilderness Park'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x532 at 0x7F8586136350>, 'text': "The Hanging Monastery of St. George's | The Judean Desert Valley of Wadi Qelt, Israel"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=260x195 at 0x7F85861C96D0>, 'text': 'Picture of 1941 Mercury Convertible - $65,000.00 - LV7A'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=358x537 at 0x7F85872E2F10>, 'text': 'Canupy Content by I M Choosing A Canopy Bed Tonight Goodnight Content In'}
# {'image': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=800x800 at 0x7F85CC2E7550>, 'text': 'Cocostyles bespoke premium exquisite <strong>baby</strong> shower <strong>gift</strong> baskets <strong>baby</strong> favors <strong>gift</strong> <strong>sets</strong> for newborn <strong>baby</strong> girl boy <strong>gift</strong>'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x225 at 0x7F8586177C50>, 'text': 'Other For Sale In Classic Cars In South Africa Junk Mail'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x290 at 0x7F8586177C50>, 'text': 'Children with snowman - vintage image from Old Design Shop'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x420 at 0x7F8586139850>, 'text': 'Hermanas Cafe - Oshkosh: $18 for $36 Worth of Mexican Fare and Drinks for Two at Hermanas Cafe in Oshkosh'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1200 at 0x7F858614AB10>, 'text': 'Stacked jars full of salted cantaloupe jam.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=830x1024 at 0x7F8586136E10>, 'text': 'woman getting fisting Old'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x360 at 0x7F8586123950>, 'text': 'Local organizations and veterans hung wreaths to honor veterans past and present during a Veterans Day ceremony at the Sandusky County Courthouse.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=940x500 at 0x7F8586139310>, 'text': 'Pineapple and Ginger Cake'}
# xxxx272
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=470x309 at 0x7F8586139310>, 'text': 'Primavera by Sandro Botticelli, 1482'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=308x410 at 0x7F85CC2E6E10>, 'text': 'Old Navy Sherpa-Lined Corduroy Trucker Jacket for Toddler Girls'}
# ...
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667 at 0x7F8586176450>, 'text': 'The Barn at Hawks Point Rustic Midwest Venue Intimate Indianapolis Wedding Photos'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=273x240 at 0x7F85CC2E5ED0>, 'text': 'A boy with a safety helmet riding in his bike'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x278 at 0x7F85861750D0>, 'text': '25+ best ideas about Box Bed on Pinterest | Victorian bunk ...'}
# {'image': <PIL.Image.Image image mode=RGB size=169x225 at 0x7F8586122F90>, 'text': 'Vintage Barbie-Outfit 1972 * #3482 * Fashion Peasant Pleasant'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=492x328 at 0x7F85CC2E5AD0>, 'text': 'Young man liestening music with headphones dancing in front of graffiti - AFVF00329'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x7F85CC2E5AD0>, 'text': 'The Most Exquisite Home In Paradise Valley Arizona On'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x320 at 0x7F85CC2E5AD0>, 'text': 'Cat Jolly Meow Key chain Crochet Amigurumi Sand Colour'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=648x1024 at 0x7F85861356D0>, 'text': '2 mugs of Fig Moscow Mule fall cocktail with cinnamon sticks and figs around them'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x750 at 0x7F85CC2E5AD0>, 'text': 'Organic Apples and Peanut Butter to Snack on'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F8586137090>, 'text': 'Great for Camping Lovers'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x270 at 0x7F85CC2E7490>, 'text': 'Tropical Hotel Resort Pool - Luxury Holiday Footage'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x750 at 0x7F858611AC90>, 'text': "Dog's-tooth violet (Erythronium dens-canis), mid March."}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x666 at 0x7F85861356D0>, 'text': '2003 Formula boat for sale, model of the boat is Fastech 271 & Image # 24 of 40'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=358x538 at 0x7F858611EC90>, 'text': 'my fountain this morning_small'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x326 at 0x7F85CC2E6290>, 'text': 'Link to the Go-kart Party Gloucestershire website'}
# {'image': <PIL.Image.Image image mode=RGB size=600x338 at 0x7F85CC2D6690>, 'text': 'Season one is going to have a ton of content for you to sift through, courtesy of Ubisoft.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360 at 0x7F85861C9A50>, 'text': 'Adam Levine Monologue - Saturday Night Live'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=710x375 at 0x7F85CC2E5AD0>, 'text': 'Couple kissing on bench'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=303x166 at 0x7F85CC2D6C10>, 'text': 'canapes recipes canapes a recipe for canapes with roast pork'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=572x750 at 0x7F85CF34F150>, 'text': 'Frida Kahlo. The Broken Column.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1440x975 at 0x7F8586174450>, 'text': 'the waiter works in a restaurant in a medical mask.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=678x1024 at 0x7F8586175750>, 'text': 'Jurassic, Dino, Party, Birthday, Ideas, Party Food'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=551x368 at 0x7F85CC2E7610>, 'text': "Enjoy the view of the mountains from each of our B&B's guest rooms."}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=170x169 at 0x7F8586176590>, 'text': 'picture of 1950s  - Forebody of executive retro car of 1950s with radiator bumper headlights on the city street - JPG'}
# {'image': <PIL.Image.Image image mode=RGB size=300x200 at 0x7F8586177650>, 'text': 'Picnic Basket with fruits and drinks'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x682 at 0x7F85CC2E7610>, 'text': 'Anne Kelly at work in her studio in Kent'}
# {'image': <PIL.Image.Image image mode=RGB size=454x341 at 0x7F8586177650>, 'text': 'FIRST HOLY COMMUNION DAY'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x316 at 0x7F8586177650>, 'text': 'buy discount storage sheds  garages direct  pa'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360 at 0x7F8586176410>, 'text': 'Baby Alive Doll Bakes Donuts ❤ Cooking With Baby Alive Episode 1 Sprinkles & Sugar Doughnu'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x827 at 0x7F8586177650>, 'text': 'Holiday Punch Recipe-Punch Bowl Ice Ring with Fruit'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1400x1400 at 0x7F85CC2E7490>, 'text': '3D visualization of the kitchen interior'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x900 at 0x7F85CC2E7190>, 'text': 'Whole Grain Grapefruit Ricotta Muffins. Healthy, hearty oat muffins with a sweet grapefruit glaze. Freezer friendly for make ahead breakfasts and snacks! | www.kristineskitchenblog.com'}
# {'image': <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=230x340 at 0x7F8586174890>, 'text': '10 Día de los Muertos Events to Attend this Weekend'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x763 at 0x7F85CC2E6290>, 'text': '1984 Mercedes Car Cake Front Made For A Grandfather'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x256 at 0x7F8586175750>, 'text': 'SPECIAL TO THE VINDICATOR'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=313x313 at 0x7F8586175750>, 'text': "Jesse Williams Teases Season Eight of Grey's Anatomy"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x250 at 0x7F8586176E50>, 'text': 'MFT Training: Boost Strength and Build High Performance Muscle'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=473x316 at 0x7F8586174450>, 'text': 'Young Woman Poses with Her Plymouth Automobile, Ca. 1951.-Kirn Vintage Stock-Stretched Canvas Print'}
# {'image': <PIL.Image.Image image mode=RGB size=620x331 at 0x7F858610D910>, 'text': 'Dragon Quest 11: Gameplay-Trailer und Switch-Release'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F8586176990>, 'text': 'Teddy Rose Bear With Hearts Gift For Valentine Birthday In Box Crown LED Light'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F8586136350>, 'text': '1984 to 1986 Ford Mustang for Sale on ClassicCars com on ClassicCars com'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x710 at 0x7F858611DC90>, 'text': 'Best 25  Cheese wedding cakes ideas on Pinterest'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x7F85861775D0>, 'text': 'Bodensee'}
# {'image': <PIL.Image.Image image mode=RGB size=350x254 at 0x7F85CC2E6AD0>, 'text': "Smith-Miller Emergency Towing Truck circa 1940's"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1100 at 0x7F8586148B90>, 'text': "These adorable Easter Houses are perfect for spring. Make them from the mini-gingerbread kit, and you'll love this easy project. Place them on a cake stand and use them on your Easter or Spring table. Decorate them with icing and fun candies. You and your family will love this project. #spring #easter #diy #crafts"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=620x412 at 0x7F85861CB610>, 'text': 'Alex Bumbombe was tough to match in his 1959 Lister Costin'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=760x450 at 0x7F8586177C50>, 'text': 'Fireworks light up the sky in downtown Beirut close to the Mohammed al-Amin mosque as Lebanon rings in the New Year. (Getty Images)'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F8586137910>, 'text': 'Pizzelle Recipe'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x359 at 0x7F8586137690>, 'text': "The Nanak Our 'Establishment' Historians Don't Want You To Know About"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x1120 at 0x7F8586136350>, 'text': 'winter-mail'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x355 at 0x7F8586137690>, 'text': 'Roses With Tissue Paper - tutorials paper flowers'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=344x344 at 0x7F85861356D0>, 'text': 'img_3081student_surfing'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=380x480 at 0x7F8586137090>, 'text': 'chocolate chip muffins in a large muffin tin and one in front'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x295 at 0x7F8586176C10>, 'text': 'Little Sprout™ Cotton Twirl Dress in Watercolor Floral'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F85CC2E6290>, 'text': 'Colomba - italian easter dove cake on old rustic cyan wooden board. Selective focus, free text space.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=840x630 at 0x7F8586176C10>, 'text': 'Cafe Cheesecake with Pecans and Drizzled Chocolate'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3026x1652 at 0x7F85872E17D0>, 'text': 'Mixed Use - Sports Courts'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=590x930 at 0x7F85CC2E6AD0>, 'text': 'Flower Fabric 12 - Fabric Textures'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x562 at 0x7F8586136690>, 'text': 'The Durango & Silverton Narrow Gauge Railroad on the Animas River, San Juan National Forest, Colorado USA'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=265x199 at 0x7F8586136E10>, 'text': 'Strasbourg Cathedral'}
# {'image': <PIL.Image.Image image mode=RGB size=220x275 at 0x7F85CC2E7590>, 'text': 'Steven Seagal in On Deadly Ground Poster and Photo'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x507 at 0x7F85CC2E6AD0>, 'text': 'THOMASTON, CT. 01 November 2010-110110SV02--From left, Cindy Killian of Thomaston and Penny Mullen of Southwind Farms Alpaca Farm in Watertown learn a new knitting technique from Louise Jackson of Thomaston at the Thomaston Library in Thomaston Monday. The small group got together at the library to share techniques.  They were learning how to knit more than one color with 2 circular needles. Jackson sells her knitted hat at the farm in Watertown.<br /> Steven Valenti Republican-American'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=700x405 at 0x7F8586135D50>, 'text': "A tourist tries bungee jumping at Australasia's highest Nevis bungee in Queenstown"}
# {'image': <PIL.Image.Image image mode=RGB size=454x333 at 0x7F858610E450>, 'text': 'A Bicycle Built For Two: Anderson & James'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x900 at 0x7F8586123950>, 'text': 'A young girl behind a tree'}
# {'image': <PIL.Image.Image image mode=RGB size=300x300 at 0x7F85CC2E4250>, 'text': "Vintage Russell's Crew Neck sweater"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080 at 0x7F858614AE10>, 'text': 'Kayaking at Watauga Lake'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1362 at 0x7F85CC2E5ED0>, 'text': 'Photo in Nature #bluebells #wood #nature #flowers'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667 at 0x7F85CC2E4250>, 'text': 'Wedding Specialists Scotland.jpg'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x960 at 0x7F85CC2E5ED0>, 'text': 'Black wedding cake with purple hued sugar flowers'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x240 at 0x7F85CC2E6290>, 'text': 'Spanish tapas on table'}
# {'image': <PIL.Image.Image image mode=RGB size=300x300 at 0x7F85884BEE90>, 'text': 'Bonnie Jean Toddler Nutcracker Holiday Outfit'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=239x358 at 0x7F85CC2E5ED0>, 'text': 'Fallas Pasacalles 2016-31'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F8586176990>, 'text': 'Sierra Mittens, Navy, Alpaca Blend, winter Mittens for the whole family'}
# {'image': <PIL.Image.Image image mode=RGB size=300x200 at 0x7F8586176990>, 'text': 'The girl in the Lithuanian suit.'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333 at 0x7F85CC2E7490>, 'text': 'Flower and macarons pattern on a pink background. Various flower flat lay. Top view - 144224250'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x994 at 0x7F858613AF10>, 'text': "Back row, from left: John Avila, The Pit Room; Grant Pinkerton, Pinkerton's BBQ; Patrick Feges, Southern Goods; Quy Hoang, Blood Bros. BBQ; and Cory Crawford, Burns Original BBQ. Front row from left: Josh Scott, Pizzitola's; Steve Garner, Southern Q; and Herb Taylor, Ray's BBQ Shack."}
# {'image': <PIL.Image.Image image mode=RGB size=1000x800 at 0x7F85871F1190>, 'text': 'Tucson Family Photographer, Princess Mini'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x359 at 0x7F8586177C50>, 'text': '"Joel Hodgson, right, with current ""MST3K"" host Jonah Ray."'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x720 at 0x7F85CC2E7610>, 'text': 'SIXTY Thousand dollar 2016 SEMA build! 2015 Denali on a ...'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x1104 at 0x7F8586177C50>, 'text': 'Piano Birthday Cake 10 Celebrity Birthday Cakes Piano Photo Happy Birthday Piano Cake'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=241x209 at 0x7F8586176590>, 'text': 'kitchen exciting small kitchen storage ideas with corner storage'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=765x1024 at 0x7F8586137690>, 'text': 'Captivating ... Darth Vader, Library Page | By Asfrederick For Library Page'}
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x7F858614B610>, 'text': 'Fancy Coffee Drink With Whipped Cream Sticker'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x2741 at 0x7F8586137050>, 'text': "The Duchess of Cambridge arriving for the 1st Battalion Irish Guards St.Patrick's Day Parade in 2019.  Picture by Stephen Lock / i-Images"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=399x320 at 0x7F85861486D0>, 'text': "Nat Fein, 'The Babe Bows Out (Babe Ruth)', 1948"}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=427x285 at 0x7F8586137050>, 'text': 'Riva Dolcevita for sale in United States of America for $12,700,000 (£9,122,318)'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x194 at 0x7F85871F1190>, 'text': 'Panoramic view looking down upon the boardwalk, beach, and the Atlantic Ocean...'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=360x450 at 0x7F8586176990>, 'text': 'Fred Astaire'}
# {'image': <PIL.Image.Image image mode=RGB size=300x300 at 0x7F858611DC90>, 'text': 'Vince Camuto Hot Pink Patent Leather Pumps'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1061x597 at 0x7F858613AE10>, 'text': '2 995 For Sale Classic 1964 Ford F 100 Pickup Truck Road'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1001 at 0x7F8586176290>, 'text': 'Cardiovascular Exercise How To Do It Right'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3062x2301 at 0x7F8586176290>, 'text': 'File1963 Ford Galaxie 500 front viewJPG  Wikimedia Commons'}
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=464x600 at 0x7F8586176290>, 'text': '"Whimsical Cat Art by Amanda Johnson - ""Kitty Cat Tea Time"", whimsical cat prints"'}
# 2500
# Saving the dataset (0/1 shards):   0%|          | 0/2500 [00:00<?, ? examples/s]
